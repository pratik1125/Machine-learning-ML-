# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Subplots
plt.figure(figsize = (14, 10))

#line chart
plt.subplot(2,3,1)
data = df.groupby("Pclass")['Fare'].mean()
plt.plot(data.index, data, marker='o')
plt.xticks([1, 2, 3])
plt.xlabel('Class')
plt.ylabel('Fare')

#bar chart
plt.subplot(2,3,2)
data = df['Survived'].value_counts()
plt.bar(height = data, x = data.index, color = ['red', 'blue'])
plt.xticks([0, 1])

#Scatter chart
plt.subplot(2,3,3)
plt.scatter(df['Age'], df['Fare'], c = df['Pclass'], cmap = 'viridis')
plt.xlabel('Age')
plt.ylabel('Fare')

#Area
plt.subplot(2,3,4)
index = [1, 2, 3]
count = df.Pclass.value_counts().reset_index().sort_values(by = 'index')['Pclass']
total = df.groupby("Pclass")['Fare'].sum()
plt.stackplot(index, count, total)
plt.xticks(index)
plt.legend(['Count', 'Revenue Generated'])


#pie chart
plt.subplot(2,3,5)
data = df['Pclass'].value_counts()
plt.pie(data, autopct="%.2f")
plt.legend(labels = data.index)
plt.title("Class distribution")

#histogram
plt.subplot(2,3,6)
plt.hist(df['Age'])
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()
