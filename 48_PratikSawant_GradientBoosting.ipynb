# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df=pd.read_csv("/content/salary_pre_data - salary_pre_data.csv")

# %%
df.describe()
# Out:
#         Experience         Salary
# count  1000.000000    1000.000000
# mean     14.771000  105557.899000
# std       8.341111   28256.971512
# min       1.000000   33510.000000
# 25%       7.000000   85032.000000
# 50%      15.000000  104314.000000
# 75%      22.000000  126803.750000
# max      29.000000  193016.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Experience  1000 non-null   int64
#  1   Degree      1000 non-null   object
#  2   Salary      1000 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 23.6+ KB

# %%
df.isnull().sum()
# Out:
# Experience    0
# Degree        0
# Salary        0
# dtype: int64

# %%
le=LabelEncoder()
df['Degree_le']=le.fit_transform(df['Degree'])

# %%
df.head()
# Out:
#    Experience       Degree  Salary  Degree_le
# 0           8  High School   84620          1
# 1          11          PhD  142591          3
# 2          28     Bachelor   97800          0
# 3          29  High School   96834          1
# 4          25          PhD  132157          3

# %%
x=df[['Experience']]
y=df[['Salary']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
acc=r2_score(y_test,y_pred)
acc
# Out:
# 0.15236797040832795
