# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
df=pd.read_csv("/content/Country-data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %%
df.shape
# Out:
# (167, 10)

# %%
df.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['country', 'child_mort', 'exports', 'health', 'imports', 'income',
#        'inflation', 'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.scatter(df.child_mort,df.gdpp)
plt.xlabel("child_mort")
plt.ylabel("gdpp")

plt.subplot(2,4,2)
plt.scatter(df.exports,df.gdpp)
plt.xlabel("Exports")

plt.subplot(2,4,3)
plt.scatter(df.health,df.gdpp)
plt.xlabel("health")

plt.subplot(2,4,4)
plt.scatter(df.imports,df.gdpp)
plt.xlabel("Imports")

plt.subplot(2,4,5)
plt.scatter(df.inflation,df.gdpp)
plt.xlabel("Inflation")

plt.subplot(2,4,6)
plt.scatter(df.life_expec,df.gdpp)
plt.title("life_expec")

plt.subplot(2,4,7)
plt.scatter(df.total_fer,df.gdpp)
plt.title("total_fer")

plt.subplot(2,4,8)
plt.scatter(df.income,df.gdpp)
plt.title("Income")
# Out:
# Text(0.5, 1.0, 'Income')

# %%
scaler = MinMaxScaler()

# %%
data=df.drop("country",axis=1)

# %%
scaler = MinMaxScaler().fit_transform(data)
df_0 = pd.DataFrame(scaler, columns=data.columns)

# %%
sns.heatmap(data.corr(),annot=True,cmap='viridis')
plt.title('Correlation of Numerical Columns')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.scatter(df_0.child_mort,df_0.gdpp)
plt.xlabel("child_mort")
plt.ylabel("gdpp")

plt.subplot(2,4,2)
plt.scatter(df_0.exports,df_0.gdpp)
plt.xlabel("Exports")

plt.subplot(2,4,3)
plt.scatter(df_0.health,df_0.gdpp)
plt.xlabel("health")

plt.subplot(2,4,4)
plt.scatter(df_0.imports,df_0.gdpp)
plt.xlabel("Imports")

plt.subplot(2,4,5)
plt.scatter(df_0.inflation,df_0.gdpp)
plt.xlabel("Inflation")

plt.subplot(2,4,6)
plt.scatter(df_0.life_expec,df_0.gdpp)
plt.title("life_expec")

plt.subplot(2,4,7)
plt.scatter(df_0.total_fer,df_0.gdpp)
plt.title("total_fer")

plt.subplot(2,4,8)
plt.scatter(df_0.income,df_0.gdpp)
plt.title("Income")
# Out:
# Text(0.5, 1.0, 'Income')
