# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('HousePrice.csv')
df
# Out:
#    Area     Price
# 0   600   6500000
# 1  1000  10800000
# 2  1200  11500000
# 3  1600  19500000
# 4  2000  21000000

# %%
plt.figure(figsize=(10,7))
plt.xlabel('Flat Area')
plt.ylabel('Sales Price')
plt.scatter(df.Area,df.Price,marker="+",color='red')

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['Area']],df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[1900]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20758561.64383562])

# %%
m=reg.coef_

# %%
c=reg.intercept_

# %%
y=m*1900+c
y
# Out:
# array([20758561.64383562])

# %%
   sal=pd.read_csv('Salary.csv')
   sal
# Out:
#    year experices  salary (in $1000s)
# 0               3                  30
# 1               8                  57
# 2               9                  64
# 3              13                  72
# 4               3                  36
# 5               6                  43
# 6              11                  59
# 7              21                  90
# 8               1                  20
# 9              16                  83

# %%
sf=sal.rename(columns={"year experices":"year","salary (in $1000s)":"salary"})
sf
# Out:
#    year  salary
# 0     3      30
# 1     8      57
# 2     9      64
# 3    13      72
# 4     3      36
# 5     6      43
# 6    11      59
# 7    21      90
# 8     1      20
# 9    16      83

# %%
plt.figure(figsize=(10,7))
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.scatter(sf.year,sf.salary,marker="+",color='red')

# %%
reg=linear_model.LinearRegression()
reg.fit(sf[['year']],sf['salary'])
# Out:
# LinearRegression()

# %%
reg.predict([[10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([58.58372806])
